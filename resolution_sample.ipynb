# %% [markdown]
# The goal of this notebook is to select a sample of chunks from the dataset where we will manually analyze their resolution.
# To determine the sample size, we used Cochran’s sample size formula (Israel 1992), using maximum variability of 0.5, confidence level of 99% and error level of 10%. The calculated sample size is 166 chunks.
#
# Used this calculator: https://www.socscistatistics.com/tests/samplesize/default.aspx
#
# Israel GD (1992) Determining sample size. Tech. rep., University of Florida

# %%
import pandas as pd
import analysis_util
import matplotlib.pyplot as plt
import json
from IPython.display import display, HTML
from math import sqrt

# %%
data_folder = "/Users/heleno/Documents/data"
analysis_util.data_folder = data_folder
SAMPLE_SIZE = 166

# %%
all_chunks_attributes = pd.read_csv(f'{data_folder}/dataset_attributes.csv')

# %%
df = pd.read_csv(f'{data_folder}/resolution_composition.csv')
print(len(df))
df.head()
# Out:
# 13573
#    chunk_id  v1_percentage  v2_percentage  normalized_v1_percentage  \
# 0    776662           0.42           0.92                      0.25
# 1    776782           0.57           0.75                      0.41
# 2    776793           0.75           0.25                      0.75
# 3    776828           0.33           0.67                      0.33
# 4    776863           0.25           0.75                      0.25
#
#    normalized_v2_percentage  intersection_percentage  \
# 0                      0.75                     0.33
# 1                      0.59                     0.32
# 2                      0.25                     0.00
# 3                      0.67                     0.00
# 4                      0.75                     0.00
#
#                                    chunk_composition  missing_v1_lines  \
# 0                       v1 v2 (v1_2) v1 (v1_2) v1 v2                 1
# 1   v2 v1 (v1_2) v1 (v1_2) v1 (v1_2) v2 (v1_2) v2...                 2
# 2                                              v2 v1                 1
# 3                                           v2 v1 v2                 2
# 4                                              v2 v1                 0
#
#    missing_v2_lines  missing_v1_lines_perc  missing_v2_lines_perc  v1_size  \
# 0                 1                  16.67                   8.33        6
# 1                 4                   6.06                   7.55       33
# 2                 0                  25.00                   0.00        4
# 3                 0                  66.67                   0.00        3
# 4                 1                   0.00                  25.00        1
#
#    v2_size  chunk_size_delta
# 0       12               6.0
# 1       53              20.0
# 2        1              -3.0
# 3        2              -1.0
# 4        4               3.0

# %%
df_po = pd.read_csv(f'{data_folder}/partial_order_result.csv')
df = pd.merge(df, df_po, on='chunk_id', how='inner', suffixes=('', ''))
df.head()
# Out:
#    chunk_id  v1_percentage  v2_percentage  normalized_v1_percentage  \
# 0    776662           0.42           0.92                      0.25
# 1    776782           0.57           0.75                      0.41
# 2    776793           0.75           0.25                      0.75
# 3    776828           0.33           0.67                      0.33
# 4    776863           0.25           0.75                      0.25
#
#    normalized_v2_percentage  intersection_percentage  \
# 0                      0.75                     0.33
# 1                      0.59                     0.32
# 2                      0.25                     0.00
# 3                      0.67                     0.00
# 4                      0.75                     0.00
#
#                                    chunk_composition  missing_v1_lines  \
# 0                       v1 v2 (v1_2) v1 (v1_2) v1 v2                 1
# 1   v2 v1 (v1_2) v1 (v1_2) v1 (v1_2) v2 (v1_2) v2...                 2
# 2                                              v2 v1                 1
# 3                                           v2 v1 v2                 2
# 4                                              v2 v1                 0
#
#    missing_v2_lines  missing_v1_lines_perc  missing_v2_lines_perc  v1_size  \
# 0                 1                  16.67                   8.33        6
# 1                 4                   6.06                   7.55       33
# 2                 0                  25.00                   0.00        4
# 3                 0                  66.67                   0.00        3
# 4                 1                   0.00                  25.00        1
#
#    v2_size  chunk_size_delta partial_order  chunk_size  resolution_size
# 0       12               6.0          True          18               12
# 1       53              20.0          True         113              101
# 2        1              -3.0          True           6                5
# 3        2              -1.0          True           5                3
# 4        4               3.0          True           6                5

# %%
malformed_chunks = pd.read_csv(f'{data_folder}/malformed_chunks.csv')
malformed_chunks = malformed_chunks['chunk_id'].unique()
print(f'Removing {len(malformed_chunks)} malformed chunks')
df = df[~df['chunk_id'].isin(malformed_chunks)]
print(f'Total number of chunks: {len(df)}')
# Out:
# Removing 264 malformed chunks
# Total number of chunks: 13309

# %%
# remove imprecise resolutions
df = df[df['v1_percentage']!= -1]
print(len(df))
# Out:
# 10726

# %%
# remove implicit forks
df = analysis_util.filter_implicit_forks(df)
print(f'New total number of chunks: {len(df)}')
# Out:
# Total projects:  1082
# Filtered 6 of 1082 projects for being implicit forks: {'IceColdSandwich/android_frameworks_base', 'AOKP/frameworks_base_disabled', 'adetaylor/android-frameworks-base-with-remote-control-service', 'RealVNC/android-frameworks-base-with-screenshot-tweaks', 'allwinner-ics/platform_frameworks_base', 'cgjones/android-frameworks-base'}
# Total valid projects:  1076
# New total number of chunks: 10177

# %%
df_descriptive = df.describe()
df_descriptive
# Out:
#            chunk_id  v1_percentage  v2_percentage  normalized_v1_percentage  \
# count  1.017700e+04    10177.00000   10177.000000              10177.000000
# mean   1.097355e+06        0.55345       0.533306                  0.510045
# std    2.119343e+05        0.31901       0.320762                  0.304105
# min    7.766620e+05        0.00000       0.000000                  0.000000
# 25%    9.398230e+05        0.33000       0.330000                  0.330000
# 50%    1.064856e+06        0.50000       0.500000                  0.500000
# 75%    1.258354e+06        0.81000       0.800000                  0.700000
# max    1.658666e+06        1.00000       1.000000                  1.000000
#
#        normalized_v2_percentage  intersection_percentage  missing_v1_lines  \
# count              10177.000000             10177.000000      10177.000000
# mean                   0.489930                 0.086609          1.823622
# std                    0.304072                 0.198059          6.835704
# min                    0.000000                 0.000000          0.000000
# 25%                    0.300000                 0.000000          0.000000
# 50%                    0.500000                 0.000000          1.000000
# 75%                    0.670000                 0.000000          1.000000
# max                    1.000000                 1.000000        353.000000
#
#        missing_v2_lines  missing_v1_lines_perc  missing_v2_lines_perc  \
# count      10177.000000           10177.000000           10177.000000
# mean           2.175789              32.502489              36.404496
# std           10.463504              29.994432              30.863874
# min            0.000000               0.000000               0.000000
# 25%            0.000000               0.000000               0.000000
# 50%            1.000000              33.330000              40.000000
# 75%            2.000000              50.000000              50.000000
# max          689.000000             100.000000             100.000000
#
#            v1_size       v2_size  chunk_size_delta    chunk_size  \
# count  10177.00000  10177.000000      10177.000000  10177.000000
# mean       6.79493      6.965216          0.170286     15.298418
# std       30.51060     33.251309         20.674248     68.754593
# min        0.00000      0.000000       -388.000000      2.000000
# 25%        2.00000      2.000000         -2.000000      4.000000
# 50%        2.00000      3.000000          0.000000      6.000000
# 75%        5.00000      5.000000          2.000000     12.000000
# max     1352.00000   1402.000000       1401.000000   2922.000000
#
#        resolution_size
# count     10177.000000
# mean          8.516164
# std          36.407157
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           7.000000
# max        1557.000000

# %%
sample = df.sample(n=SAMPLE_SIZE, random_state=33)
sample_descriptive = sample.describe()
sample_descriptive
# Out:
#            chunk_id  v1_percentage  v2_percentage  normalized_v1_percentage  \
# count  1.660000e+02     166.000000     166.000000                166.000000
# mean   1.115454e+06       0.567952       0.535723                  0.515843
# std    2.119402e+05       0.302075       0.315036                  0.290969
# min    7.769480e+05       0.000000       0.000000                  0.000000
# 25%    9.614592e+05       0.500000       0.330000                  0.330000
# 50%    1.079062e+06       0.500000       0.500000                  0.500000
# 75%    1.299988e+06       0.800000       0.830000                  0.670000
# max    1.610560e+06       1.000000       1.000000                  1.000000
#
#        normalized_v2_percentage  intersection_percentage  missing_v1_lines  \
# count                166.000000               166.000000        166.000000
# mean                   0.484157                 0.103373          1.433735
# std                    0.290969                 0.207153          2.107377
# min                    0.000000                 0.000000          0.000000
# 25%                    0.330000                 0.000000          0.000000
# 50%                    0.500000                 0.000000          1.000000
# 75%                    0.670000                 0.080000          1.000000
# max                    1.000000                 1.000000         15.000000
#
#        missing_v2_lines  missing_v1_lines_perc  missing_v2_lines_perc  \
# count        166.000000             166.000000             166.000000
# mean           1.765060              32.150663              37.517108
# std            2.607492              29.181130              30.395041
# min            0.000000               0.000000               0.000000
# 25%            1.000000               0.000000               3.012500
# 50%            1.000000              33.330000              50.000000
# 75%            2.000000              50.000000              50.000000
# max           20.000000             100.000000             100.000000
#
#           v1_size     v2_size  chunk_size_delta  chunk_size  resolution_size
# count  166.000000  166.000000        166.000000  166.000000       166.000000
# mean     4.933735    5.506024          0.572289   11.620482         7.096386
# std      6.041408    8.513623          9.131574   13.336005         9.716109
# min      0.000000    0.000000        -38.000000    2.000000         1.000000
# 25%      2.000000    2.000000         -1.000000    4.000000         2.000000
# 50%      3.000000    3.000000          0.000000    7.000000         3.000000
# 75%      6.000000    6.000000          2.000000   13.750000         8.000000
# max     38.000000   76.000000         76.000000   90.000000        70.000000

# %%
# standard error for the sample = standard deviation of the dataset / sqrt of the sample size
data = []
for column in df_descriptive.columns:
    if 'chunk_id' not in column:
        df_value = df_descriptive.loc['mean'][column]
        df_std = df_descriptive.loc['std'][column]
        sample_value = sample_descriptive.loc['mean'][column]
        standard_error = df_descriptive.loc['std'][column] / sqrt(SAMPLE_SIZE)
        sample_range_lower = df_value - standard_error
        sample_range_upper = df_value + standard_error
        is_within = (sample_value <= sample_range_upper) and (sample_value >= sample_range_lower)
#         variability = df_value - sample_value
#         variability_perc = (variability * 100) / df_value
    #     else:
    #         variability = sample_value - df_value
        data.append([column, df_value, df_std, standard_error, sample_range_lower, sample_range_upper, sample_value, is_within])
pd.DataFrame(data, columns=['metric', 'dataset_mean', 'dataset_std', 'standard error', 'sample lower range', 'sample upper range', 'sample_mean', 'is within?'])
# Out:
#                       metric  dataset_mean  dataset_std  standard error  \
# 0              v1_percentage      0.553450     0.319010        0.024760
# 1              v2_percentage      0.533306     0.320762        0.024896
# 2   normalized_v1_percentage      0.510045     0.304105        0.023603
# 3   normalized_v2_percentage      0.489930     0.304072        0.023601
# 4    intersection_percentage      0.086609     0.198059        0.015372
# 5           missing_v1_lines      1.823622     6.835704        0.530554
# 6           missing_v2_lines      2.175789    10.463504        0.812125
# 7      missing_v1_lines_perc     32.502489    29.994432        2.328019
# 8      missing_v2_lines_perc     36.404496    30.863874        2.395501
# 9                    v1_size      6.794930    30.510600        2.368082
# 10                   v2_size      6.965216    33.251309        2.580802
# 11          chunk_size_delta      0.170286    20.674248        1.604633
# 12                chunk_size     15.298418    68.754593        5.336391
# 13           resolution_size      8.516164    36.407157        2.825743
#
#     sample lower range  sample upper range  sample_mean  is within?
# 0             0.528690            0.578210     0.567952        True
# 1             0.508411            0.558202     0.535723        True
# 2             0.486442            0.533648     0.515843        True
# 3             0.466330            0.513531     0.484157        True
# 4             0.071237            0.101981     0.103373       False
# 5             1.293068            2.354175     1.433735        True
# 6             1.363663            2.987914     1.765060        True
# 7            30.174469           34.830508    32.150663        True
# 8            34.008995           38.799998    37.517108        True
# 9             4.426848            9.163012     4.933735        True
# 10            4.384414            9.546018     5.506024        True
# 11           -1.434347            1.774919     0.572289        True
# 12            9.962027           20.634809    11.620482        True
# 13            5.690420           11.341907     7.096386        True

# %%
sample.head()
# Out:
#        chunk_id  v1_percentage  v2_percentage  normalized_v1_percentage  \
# 10515   1310670            0.5           0.50                      0.50
# 11270   1374858            0.5           0.83                      0.33
# 8957    1159289            0.0           1.00                      0.00
# 7636    1111021            0.5           0.50                      0.50
# 7404    1106228            0.5           0.50                      0.50
#
#        normalized_v2_percentage  intersection_percentage chunk_composition  \
# 10515                      0.50                     0.00             v2 v1
# 11270                      0.67                     0.33      (v1_2) v1 v2
# 8957                       1.00                     0.00                v2
# 7636                       0.50                     0.00             v1 v2
# 7404                       0.50                     0.00             v1 v2
#
#        missing_v1_lines  missing_v2_lines  missing_v1_lines_perc  \
# 10515                 0                 1                    0.0
# 11270                 3                 0                   50.0
# 8957                  1                 2                  100.0
# 7636                  0                 1                    0.0
# 7404                  1                 2                   50.0
#
#        missing_v2_lines_perc  v1_size  v2_size  chunk_size_delta  \
# 10515                  50.00        1        2               1.0
# 11270                   0.00        6        5              -1.0
# 8957                   66.67        1        3               2.0
# 7636                   50.00        1        2               1.0
# 7404                   66.67        2        3               1.0
#
#       partial_order  chunk_size  resolution_size
# 10515          True           3                2
# 11270          True          13                7
# 8957           True           4                1
# 7636           True           3                2
# 7404           True           7                2

# %%
file = f'{data_folder}/dataset.json'
with open(file) as f:
    data_listofdict = json.load(f)
dataset_complete = pd.DataFrame.from_dict(data_listofdict)
dataset_complete.head()
# Out:
#    chunk_id                                                 v1  \
# 0    776662          if (response.getResponseCode() == 200 ...
# 1    776782      this.outgoingOrdinals = createOrdinals( so...
# 2    776793        this.ordinals = processEdge.getIncomingO...
# 3    776828            flowStepStats.markFailed( throwable ...
# 4    776863    public Map<Object, Object> getDefaultPropert...
#
#                                                   v2  \
# 0              if (response.getResponseCode() == ...
# 1      this.sourceProcessID = sourceProcess.getID...
# 2        this.ordinals = processEdge.getSourcePro...
# 3            flowStepStats.markFailed( this.throw...
# 4    {\n  Update.registerPlanner( getClass() );\n...
#
#                                                 base  \
# 0  package net.threescale.api.v2;\n\nimport net.t...
# 1  /*\n * Copyright (c) 2007-2015 Concurrent, Inc...
# 2  /*\n * Copyright (c) 2007-2015 Concurrent, Inc...
# 3  /*\n * Copyright (c) 2007-2015 Concurrent, Inc...
# 4  /*\n * Copyright (c) 2007-2014 Concurrent, Inc...
#
#                                             solution  \
# 0  \n            log.info("response code was: " +...
# 1    public ProcessEdge( ElementGraph sourceEleme...
# 2        {\n      this.config = config;\n      th...
# 3  \n        if( this.throwable != null )\n      ...
# 4      return DebugLevel.valueOf( debugLevel );\n...
#
#                                       before_context  \
# 0  \n            log.info("response code was: " +...
# 1  \n  public ProcessEdge( ElementGraph sourceEle...
# 2        {\n      this.config = config;\n      th...
# 3  \n        if( this.throwable != null )\n      ...
# 4      return DebugLevel.valueOf( debugLevel );\n...
#
#                                        after_context
# 0                                     }\n    }\n\n\n
# 1      }\n\n  private Set<Integer> createOrdinals...
# 2        }\n\n    public FlowElement getFlowEleme...
# 3                   }\n        else\n          {\n\n
# 4        {\n    return defaultProperties;\n    }\n\n

# %%
sample_data = dataset_complete[dataset_complete['chunk_id'].isin(sample['chunk_id'].unique())]
sample_data.head()
# Out:
#      chunk_id                                                 v1  \
# 10     776948    public static <R> R returnInstanceFieldIfExi...
# 81     777948          assert(b2.toFEN().equals("k7/8/P7/8/8/...
# 116    778595          mDeck = deck;\n        sSeriesList = g...
# 187    779647              mSpaceUntil.substring(0, mSpaceUnt...
# 188    779688              cursor = mDatabase.rawQuery(query,...
#
#                                                     v2  \
# 10     public static Object invokeConstructor( Stri...
# 81           assert(b2.toFEN().equals("k7/8/P7/8/8/...
# 116          sDeck = deck;\n        if (type == TYP...
# 187              spaceUntil.substring(0, spaceUntil...
# 188              cursor = database.rawQuery(query, ...
#
#                                                   base  \
# 10   /*\n * Copyright (c) 2007-2014 Concurrent, Inc...
# 81   // Oliver Kullmann, 6.12.2010 (Swansea)\n\ncla...
# 116  /*********************************************...
# 187  /*********************************************...
# 188  /*********************************************...
#
#                                               solution  \
# 10         }\n    }\n\n  public static <R> R return...
# 81           b2.do_normal_white_move('h','2','h','4...
# 116  \n    public static boolean refreshDeckStatist...
# 187              for (Field f : getFields()) {\n   ...
# 188          Cursor cursor = null;\n\n        try {...
#
#                                         before_context  \
# 10                                        }\n    }\n\n
# 81           b2.do_normal_white_move('h','2','h','4...
# 116  \n    public static boolean refreshDeckStatist...
# 187              for (Field f : getFields()) {\n   ...
# 188           Cursor cursor = null;\n\n        try {\n
#
#                                          after_context
# 10                             {\n    try\n      {\n\n
# 81         }\n      // testing setting and resettin...
# 116                                     }\n    }\n\n\n
# 187              for (Card card : getUpdatedRelated...
# 188              String methodName = getCursorMetho...

# %%
#sample_data[['chunk_id', 'solution']].to_csv('test.csv')

# %%
sample_data.sample(16)
# Out:
#        chunk_id                                                 v1  \
# 7733    1113875  \t\tv = T.setNodeV(new BSTNode(T, K = x));\n\t...
# 11507   1393203      public abstract NavigationStore getNavigat...
# 12207   1418870  import io.realm.entities.Dog;\nimport io.realm...
# 7742    1113895  \t\tv = T.setNodeV(new AANode(T, K = x));\n\t\...
# 10515   1310670  public class PrimitiveType extends Annotatable...
# 5783    1039380                  final String epoch = sourcePro...
# 11219   1371887  \tpublic static final Set<String> identifiers ...
# 2867     930236      public List<String> lrange(String key, int...
# 9009    1159572  import com.google.common.base.Predicate;\nimpo...
# 10967   1361290                          .machine(machine.get())\n
# 4155     974594      private static X509Certificate[] createCha...
# 10856   1339202  // The update hook is not invoked when interna...
# 2792     935707      /**\n     * Asynchronously refreshes the e...
# 6253    1055401          super(persistenceUnits, properties, me...
# 330      782705
# 8725    1151703      \t\t} else if (c instanceof ClasspathJar) {\n
#
#                                                       v2  \
# 7733   \t\tv = T.v = new BSTNode(T, K = x);\n\t\tv.bg...
# 11507      public abstract SiteService getSiteService...
# 12207        import io.realm.entities.AnnotationTypes;\n
# 7742   \t\tT.v = v = new AANode(T, K = x);\n\t\tv.get...
# 10515  @SuppressWarnings({"rawtypes", "unchecked"})\n...
# 5783                   final LCMetadata lcMetadata = ...
# 11219  \tpublic static final Set<String> identifiers ...
# 2867       public List<String> lrange(final String ke...
# 9009   import java.lang.Thread.UncaughtExceptionHandl...
# 10967                      .machine((SshMachineLocati...
# 4155       private static X509Certificate[] createCha...
# 10856  /**\n * Data change notification callback.\n *...
# 2792       public IndexEventListener getIndexEventLis...
# 6253           super(persistenceUnits, properties);\n...
# 330        ModuleVersionArtifactMetaData artifact(Str...
# 8725   \t\t\tout.writeUTF(cd.externalAnnotationPath !...
#
#                                                     base  \
# 7733   package algvis.bst;\n\nimport algvis.core.Algo...
# 11507  /*\n * Copyright (C) 2012 eXo Platform SAS.\n ...
# 12207  package io.realm;\n\nimport android.test.Andro...
# 7742   package algvis.aatree;\n\nimport algvis.bst.BS...
# 10515  /*********************************************...
# 5783   package org.esa.cci.lc.conversion;\n\nimport o...
# 11219  package de.uni_leipzig.simba.saim.core.metric;...
# 2867   package redis.clients.jedis;\n\nimport java.io...
# 9009   /*\n * Copyright 2010-2011 Ning, Inc.\n *\n * ...
# 10967  package brooklyn.entity.database.postgresql;\n...
# 4155   /*\n *  Licensed to the Apache Software Founda...
# 10856  package org.sqlite;\n\nimport com.sun.jna.Call...
# 2792   /*\n * Licensed to Elasticsearch under one or ...
# 6253   /*********************************************...
# 330    /*\n * Copyright 2012 the original author or a...
# 8725   /*********************************************...
#
#                                                 solution  \
# 7733   \tpublic BSTInsert(BST T, int x) {\n\t\tsuper(...
# 11507  \n    public abstract LayoutService getLayoutS...
# 12207  import java.io.IOException;\n\nimport io.realm...
# 7742   \tpublic AAInsert(AA T, int x) {\n\t\tsuper(T)...
# 10515   * @since 2.0\n * @noinstantiate This class is...
# 5783               @Override\n            public Obje...
# 11219  public class Measure extends Node\n{\n\tpublic...
# 2867        * @return Multi bulk reply, specifically ...
# 9009   \npackage com.ning.billing.entitlement.engine....
# 10967  \n            feed = SshFeed.builder()\n      ...
# 4155           return createChain(certs[issuerSertInd...
# 10856  import jnr.ffi.annotations.Delegate;\nimport j...
# 2792           return percolatorQueriesRegistry.stats...
# 6253        */\n    public MetamodelConfiguration(Map...
# 330    \n    ModuleVersionArtifactMetaData artifact(A...
# 8725   \t\t\tout.writeUTF(cd.binaryFolder.getFullPath...
#
#                                           before_context  \
# 7733   \tpublic BSTInsert(BST T, int x) {\n\t\tsuper(...
# 11507  \n    public abstract LayoutService getLayoutS...
# 12207  import java.io.IOException;\n\nimport io.realm...
# 7742   \tpublic AAInsert(AA T, int x) {\n\t\tsuper(T)...
# 10515   * @since 2.0\n * @noinstantiate This class is...
# 5783               @Override\n            public Obje...
# 11219  public class Measure extends Node\n{\n\tpublic...
# 2867        * @return Multi bulk reply, specifically ...
# 9009   \npackage com.ning.billing.entitlement.engine....
# 10967  \n            feed = SshFeed.builder()\n      ...
# 4155           return createChain(certs[issuerSertInd...
# 10856  import jnr.ffi.annotations.Delegate;\nimport j...
# 2792           return percolatorQueriesRegistry.stats...
# 6253        */\n    public MetamodelConfiguration(Map...
# 330    \n    ModuleVersionArtifactMetaData artifact(A...
# 8725   \t\t\tout.writeUTF(cd.binaryFolder.getFullPath...
#
#                                            after_context
# 7733              \t\tsetHeader("insertion");\n\t}\n\n\n
# 11507  \n    public abstract DescriptionStore getDesc...
# 12207  import io.realm.exceptions.RealmMigrationNeede...
# 7742              \t\tsetHeader("insertion");\n\t}\n\n\n
# 10515  \n\t/**\n \t * Primitive type codes (typesafe ...
# 5783                                                s...
# 11219  \n\t@Override public Set<String> identifiers()...
# 2867           client.lrange(key, start, end);\n     ...
# 9009   \npublic abstract class ApiEventProcessorBase ...
# 10967                      .poll(new SshPollConfig<Bo...
# 4155   \n        // Signer is self-signed\n        if...
# 10856  \t/**\n\t * Data Change Notification Callback\...
# 2792           @Override\n        public void run() {...
# 6253                                     }\n\n    /*\n\n
# 330                     boolean isMetaDataOnly();\n}\n\n
# 8725   \t\t\tClasspathJar jar = (ClasspathJar) c;\n\t...

# %%
sample_data[sample_data['chunk_id'] == 782705]
# Out:
#      chunk_id v1                                                 v2  \
# 330    782705         ModuleVersionArtifactMetaData artifact(Str...
#
#                                                   base  \
# 330  /*\n * Copyright 2012 the original author or a...
#
#                                               solution  \
# 330  \n    ModuleVersionArtifactMetaData artifact(A...
#
#                                         before_context  \
# 330  \n    ModuleVersionArtifactMetaData artifact(A...
#
#                             after_context
# 330      boolean isMetaDataOnly();\n}\n\n
